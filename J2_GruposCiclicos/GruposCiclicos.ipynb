# %% [markdown]
# <h1>Taller #2: Cálculo del número de generadores del Grupo Cíclico de G</h1>

# %% [markdown]
# <h4> Presentado por: David Santiago Cruz Hernandez</h4>
# <h4> Asignatura: Matemáticas Discretas II </h4>

# %%
import time
numGeneradoresGCiclico = 0
dicDescomposicionPrimosGrupo = {}

# %%
def bold(texto):
    return "\033[1m" + texto + "\033[0m"

# %%
def imprimirSuperIndice(indice):
    if indice == 1:
        return str(chr(0x00b9))
    elif 2 <= indice <= 3:
        return str(chr(0x00b0 + indice))
    else:
        return str(chr(0x2070 + indice))

# %% [markdown]
# #### Ingreso de N:

# %%
n = int(input("Ingrese el Orden de G:"))

# %%
Grupo = []
for num in range(1,n+1):
    Grupo.append(num)

# %% [markdown]
# ### Metodo Alternativo:
# ##### Comprobación por medio del siguiente *Lema*:

# %% [markdown]
# ###### • **i)** φ(I) = 1
# ###### • **ii)** Si *p* es **primo**, entonces el **φ($p^{a}$) =** $p^{a}$ - $p^{a-1}$
# ###### • **iii)** Si *mcd(m,n)* = 1, entonces el **φ(m•n) =** φ(m) + φ(n)

# %%
def calcularDescomposicionPrimos(resultadoDivision,dicDescomposicionPrimos):
    potencia = 1
    for divisor in range(2,len(Grupo)):
        while resultadoDivision%divisor==0:
            resultadoDivision = resultadoDivision/divisor
            if divisor not in dicDescomposicionPrimos:
                potencia = 1
            dicDescomposicionPrimos[divisor] = potencia
            potencia+=1
        if resultadoDivision ==1:
            break
    return dicDescomposicionPrimos

# %%
def LemaTotientEulerPrimos():
    resultado = 1
    for primo in dicDescomposicionPrimosGrupo:
        indice = dicDescomposicionPrimosGrupo.get(primo)
        resultado = resultado * (pow(primo,indice) - pow(primo,indice-1))
    return resultado

# %%
def imprimirCadenaDescomposicion():
    strDescomposicion = ""
    for base in dicDescomposicionPrimosGrupo:
        strIndice = imprimirSuperIndice(dicDescomposicionPrimosGrupo[base])
        strDescomposicion = strDescomposicion + str(base) + strIndice + "•"
    return strDescomposicion[0:-1]

# %%
def imprimirCadenaDescomposicionTotient():
    strLemaIII = ""
    for potencia in imprimirCadenaDescomposicion().split("•"):
        strLemaIII = strLemaIII + "φ(" + potencia + ")•"

    strLemaII = ""
    for base in dicDescomposicionPrimosGrupo:
        strLemaII = strLemaII + "(" + str(base) + imprimirSuperIndice(dicDescomposicionPrimosGrupo[base]) + "-" + str(base) + imprimirSuperIndice(dicDescomposicionPrimosGrupo[base] - 1) + ")•"
    return strLemaIII[0:-1] + " = " + strLemaII[0:-1]

# %%
def imprimirMetodoAlternativo():
    print("                    " + bold("Orden del Grupo G: " + str(n)) + "\n")
    print("Tiempo de ejecución del Metodo Alternativo: " + str(Tiempo2) + " segundos.")
    print("→ Descomposición de Factores Primos de " + bold("n") + ": " + imprimirCadenaDescomposicion())
    print(bold("→ Número de Generadores Cíclicos de G:"))
    print("      φ(" + str(n) + ") = φ(" + imprimirCadenaDescomposicion() + ") = " + imprimirCadenaDescomposicionTotient() + " = " + str(numGeneradoresGCiclico) )
    print("→ Por este Metodo, no se obtiene la lista de los Generadores Cíclicos de G, ni los SubGrupos generados.")

# %% [markdown]
# ###### Ejecutar el Metodo Alternativo:

# %%
inicio2 = time.time()
dicDescomposicionPrimosGrupo = calcularDescomposicionPrimos(len(Grupo), {})
numGeneradoresGCiclico = LemaTotientEulerPrimos()

fin2 = time.time()
Tiempo2 = round(fin2-inicio2,4)

imprimirMetodoAlternativo()
# Out:
#                     Orden del Grupo G: 14500
#
# Tiempo de ejecución del Metodo Alternativo: 0.0 segundos.
# → Descomposición de Factores Primos de n: 2²•5³•29¹
# → Número de Generadores Cíclicos de G:
#       φ(14500) = φ(2²•5³•29¹) = φ(2²)•φ(5³)•φ(29¹) = (2²-2¹)•(5³-5²)•(29¹-29⁰) = 5600
# → Por este Metodo, no se obtiene la lista de los Generadores Cíclicos de G, ni los SubGrupos generados.

# %% [markdown]
# ### Método Totient de Euler:
# ##### Comprobación de cada elemento de G. Si mcd(x,n) = 1, entonces ese elemento genera un Grupo Cíclico:

# %%
def calcularMCDconGrupo(numGenerador):
    listaPrimosComunes = []
    mcd = 1
    descPrimosNumGenerador = calcularDescomposicionPrimos(numGenerador, {})
    menorRepeticion = lambda x, y: x if x <= y else y
    for primo in descPrimosNumGenerador:
        if primo in dicDescomposicionPrimosGrupo:
            listaPrimosComunes.append(
                pow(primo, menorRepeticion(descPrimosNumGenerador[primo], dicDescomposicionPrimosGrupo[primo])) )
    for primo in listaPrimosComunes:
        mcd = mcd * primo
    return mcd

# %%
def generadorTotient(numGenerador):
    strIndice = ""
    mcd = calcularMCDconGrupo(numGenerador)
    for digit in str(numGenerador):
        strIndice = strIndice + imprimirSuperIndice(int(digit))
    if mcd == 1:
        print("< a" + strIndice + "> = " + bold("--- Grupo Cíclico de G ---"))
        return True
    else:
        if mcd == numGenerador or mcd == 1:
            print("< a" + strIndice + "> = " + "Subgrupo Cíclico generado por si MISMO")
        else:
            print("< a" + strIndice + "> = " + "Subgrupo Cíclico generado por " + str(mcd))

        return False

# %%
def imprimirMetodoTotient():
    print("                                   " + bold("Orden del Grupo G: " + str(n)) + "\n")
    print(bold("→ Generadores Cíclicos de G:"))
    print(bold("|") + " { " + ', '.join(str(x) for x in GeneradoresGCiclico) + " } " + bold("|" + " = " + str(numGeneradoresGCiclico))+ "\n")

    print("Tiempo de ejecución del " + bold("Metodo Totient de Euler") + ": " + str(Tiempo1) + " segundos.")
    print(bold("→ Número de Generadores Cíclicos de G: --- φ(" + str(n) + ") = " + str(numGeneradoresGCiclico) + " ---"))
    print("→ Por este Metodo, no se obtiene los elementos de los SubGrupos generados por G.")

# %% [markdown]
# ###### Ejecutar el Metodo del Totient:

# %%
GeneradoresGCiclico = []
numGeneradoresGCiclico=0
inicio1 = time.time()

for num in Grupo:
    if generadorTotient(num):
        numGeneradoresGCiclico+=1
        GeneradoresGCiclico.append(num)

fin1 = time.time()
Tiempo1 = round(fin1-inicio1,2)

imprimirMetodoTotient()
# Out:
# < a¹> = --- Grupo Cíclico de G ---
# < a²> = Subgrupo Cíclico generado por si MISMO
# < a³> = --- Grupo Cíclico de G ---
# < a⁴> = Subgrupo Cíclico generado por si MISMO
# < a⁵> = Subgrupo Cíclico generado por si MISMO
# < a⁶> = Subgrupo Cíclico generado por 2
# < a⁷> = --- Grupo Cíclico de G ---
# < a⁸> = Subgrupo Cíclico generado por 4
# < a⁹> = --- Grupo Cíclico de G ---
# < a¹⁰> = Subgrupo Cíclico generado por si MISMO
# < a¹¹> = --- Grupo Cíclico de G ---
# < a¹²> = Subgrupo Cíclico generado por 4
# < a¹³> = --- Grupo Cíclico de G ---
# < a¹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁷> = --- Grupo Cíclico de G ---
# < a¹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁹> = --- Grupo Cíclico de G ---
# < a²⁰> = Subgrupo Cíclico generado por si MISMO
# < a²¹> = --- Grupo Cíclico de G ---
# < a²²> = Subgrupo Cíclico generado por 2
# < a²³> = --- Grupo Cíclico de G ---
# < a²⁴> = Subgrupo Cíclico generado por 4
# < a²⁵> = Subgrupo Cíclico generado por si MISMO
# < a²⁶> = Subgrupo Cíclico generado por 2
# < a²⁷> = --- Grupo Cíclico de G ---
# < a²⁸> = Subgrupo Cíclico generado por 4
# < a²⁹> = Subgrupo Cíclico generado por si MISMO
# < a³⁰> = Subgrupo Cíclico generado por 10
# < a³¹> = --- Grupo Cíclico de G ---
# < a³²> = Subgrupo Cíclico generado por 4
# < a³³> = --- Grupo Cíclico de G ---
# < a³⁴> = Subgrupo Cíclico generado por 2
# < a³⁵> = Subgrupo Cíclico generado por 5
# < a³⁶> = Subgrupo Cíclico generado por 4
# < a³⁷> = --- Grupo Cíclico de G ---
# < a³⁸> = Subgrupo Cíclico generado por 2
# < a³⁹> = --- Grupo Cíclico de G ---
# < a⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁴¹> = --- Grupo Cíclico de G ---
# < a⁴²> = Subgrupo Cíclico generado por 2
# < a⁴³> = --- Grupo Cíclico de G ---
# < a⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁴⁷> = --- Grupo Cíclico de G ---
# < a⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁴⁹> = --- Grupo Cíclico de G ---
# < a⁵⁰> = Subgrupo Cíclico generado por si MISMO
# < a⁵¹> = --- Grupo Cíclico de G ---
# < a⁵²> = Subgrupo Cíclico generado por 4
# < a⁵³> = --- Grupo Cíclico de G ---
# < a⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁵⁷> = --- Grupo Cíclico de G ---
# < a⁵⁸> = Subgrupo Cíclico generado por si MISMO
# < a⁵⁹> = --- Grupo Cíclico de G ---
# < a⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁶¹> = --- Grupo Cíclico de G ---
# < a⁶²> = Subgrupo Cíclico generado por 2
# < a⁶³> = --- Grupo Cíclico de G ---
# < a⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁶⁷> = --- Grupo Cíclico de G ---
# < a⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁶⁹> = --- Grupo Cíclico de G ---
# < a⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁷¹> = --- Grupo Cíclico de G ---
# < a⁷²> = Subgrupo Cíclico generado por 4
# < a⁷³> = --- Grupo Cíclico de G ---
# < a⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁷⁷> = --- Grupo Cíclico de G ---
# < a⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁷⁹> = --- Grupo Cíclico de G ---
# < a⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁸¹> = --- Grupo Cíclico de G ---
# < a⁸²> = Subgrupo Cíclico generado por 2
# < a⁸³> = --- Grupo Cíclico de G ---
# < a⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁸⁷> = Subgrupo Cíclico generado por 29
# < a⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁸⁹> = --- Grupo Cíclico de G ---
# < a⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁹¹> = --- Grupo Cíclico de G ---
# < a⁹²> = Subgrupo Cíclico generado por 4
# < a⁹³> = --- Grupo Cíclico de G ---
# < a⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁹⁷> = --- Grupo Cíclico de G ---
# < a⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁹⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁰> = Subgrupo Cíclico generado por si MISMO
# < a¹⁰¹> = --- Grupo Cíclico de G ---
# < a¹⁰²> = Subgrupo Cíclico generado por 2
# < a¹⁰³> = --- Grupo Cíclico de G ---
# < a¹⁰⁴> = Subgrupo Cíclico generado por 4
# < a¹⁰⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁰> = Subgrupo Cíclico generado por 10
# < a¹¹¹> = --- Grupo Cíclico de G ---
# < a¹¹²> = Subgrupo Cíclico generado por 4
# < a¹¹³> = --- Grupo Cíclico de G ---
# < a¹¹⁴> = Subgrupo Cíclico generado por 2
# < a¹¹⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁶> = Subgrupo Cíclico generado por si MISMO
# < a¹¹⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁸> = Subgrupo Cíclico generado por 2
# < a¹¹⁹> = --- Grupo Cíclico de G ---
# < a¹²⁰> = Subgrupo Cíclico generado por 20
# < a¹²¹> = --- Grupo Cíclico de G ---
# < a¹²²> = Subgrupo Cíclico generado por 2
# < a¹²³> = --- Grupo Cíclico de G ---
# < a¹²⁴> = Subgrupo Cíclico generado por 4
# < a¹²⁵> = Subgrupo Cíclico generado por si MISMO
# < a¹²⁶> = Subgrupo Cíclico generado por 2
# < a¹²⁷> = --- Grupo Cíclico de G ---
# < a¹²⁸> = Subgrupo Cíclico generado por 4
# < a¹²⁹> = --- Grupo Cíclico de G ---
# < a¹³⁰> = Subgrupo Cíclico generado por 10
# < a¹³¹> = --- Grupo Cíclico de G ---
# < a¹³²> = Subgrupo Cíclico generado por 4
# < a¹³³> = --- Grupo Cíclico de G ---
# < a¹³⁴> = Subgrupo Cíclico generado por 2
# < a¹³⁵> = Subgrupo Cíclico generado por 5
# < a¹³⁶> = Subgrupo Cíclico generado por 4
# < a¹³⁷> = --- Grupo Cíclico de G ---
# < a¹³⁸> = Subgrupo Cíclico generado por 2
# < a¹³⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴¹> = --- Grupo Cíclico de G ---
# < a¹⁴²> = Subgrupo Cíclico generado por 2
# < a¹⁴³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁵> = Subgrupo Cíclico generado por si MISMO
# < a¹⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁹> = --- Grupo Cíclico de G ---
# < a¹⁵⁰> = Subgrupo Cíclico generado por 50
# < a¹⁵¹> = --- Grupo Cíclico de G ---
# < a¹⁵²> = Subgrupo Cíclico generado por 4
# < a¹⁵³> = --- Grupo Cíclico de G ---
# < a¹⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹⁵⁵> = Subgrupo Cíclico generado por 5
# < a¹⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹⁵⁷> = --- Grupo Cíclico de G ---
# < a¹⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹⁵⁹> = --- Grupo Cíclico de G ---
# < a¹⁶⁰> = Subgrupo Cíclico generado por 20
# < a¹⁶¹> = --- Grupo Cíclico de G ---
# < a¹⁶²> = Subgrupo Cíclico generado por 2
# < a¹⁶³> = --- Grupo Cíclico de G ---
# < a¹⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹⁶⁷> = --- Grupo Cíclico de G ---
# < a¹⁶⁸> = Subgrupo Cíclico generado por 4
# < a¹⁶⁹> = --- Grupo Cíclico de G ---
# < a¹⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹⁷¹> = --- Grupo Cíclico de G ---
# < a¹⁷²> = Subgrupo Cíclico generado por 4
# < a¹⁷³> = --- Grupo Cíclico de G ---
# < a¹⁷⁴> = Subgrupo Cíclico generado por 58
# < a¹⁷⁵> = Subgrupo Cíclico generado por 25
# < a¹⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹⁷⁷> = --- Grupo Cíclico de G ---
# < a¹⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹⁷⁹> = --- Grupo Cíclico de G ---
# < a¹⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹⁸¹> = --- Grupo Cíclico de G ---
# < a¹⁸²> = Subgrupo Cíclico generado por 2
# < a¹⁸³> = --- Grupo Cíclico de G ---
# < a¹⁸⁴> = Subgrupo Cíclico generado por 4
# < a¹⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹⁸⁷> = --- Grupo Cíclico de G ---
# < a¹⁸⁸> = Subgrupo Cíclico generado por 4
# < a¹⁸⁹> = --- Grupo Cíclico de G ---
# < a¹⁹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁹¹> = --- Grupo Cíclico de G ---
# < a¹⁹²> = Subgrupo Cíclico generado por 4
# < a¹⁹³> = --- Grupo Cíclico de G ---
# < a¹⁹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁹⁷> = --- Grupo Cíclico de G ---
# < a¹⁹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁹⁹> = --- Grupo Cíclico de G ---
# < a²⁰⁰> = Subgrupo Cíclico generado por 100
# < a²⁰¹> = --- Grupo Cíclico de G ---
# < a²⁰²> = Subgrupo Cíclico generado por 2
# < a²⁰³> = Subgrupo Cíclico generado por 29
# < a²⁰⁴> = Subgrupo Cíclico generado por 4
# < a²⁰⁵> = Subgrupo Cíclico generado por 5
# < a²⁰⁶> = Subgrupo Cíclico generado por 2
# < a²⁰⁷> = --- Grupo Cíclico de G ---
# < a²⁰⁸> = Subgrupo Cíclico generado por 4
# < a²⁰⁹> = --- Grupo Cíclico de G ---
# < a²¹⁰> = Subgrupo Cíclico generado por 10
# < a²¹¹> = --- Grupo Cíclico de G ---
# < a²¹²> = Subgrupo Cíclico generado por 4
# < a²¹³> = --- Grupo Cíclico de G ---
# < a²¹⁴> = Subgrupo Cíclico generado por 2
# < a²¹⁵> = Subgrupo Cíclico generado por 5
# < a²¹⁶> = Subgrupo Cíclico generado por 4
# < a²¹⁷> = --- Grupo Cíclico de G ---
# < a²¹⁸> = Subgrupo Cíclico generado por 2
# < a²¹⁹> = --- Grupo Cíclico de G ---
# < a²²⁰> = Subgrupo Cíclico generado por 20
# < a²²¹> = --- Grupo Cíclico de G ---
# < a²²²> = Subgrupo Cíclico generado por 2
# < a²²³> = --- Grupo Cíclico de G ---
# < a²²⁴> = Subgrupo Cíclico generado por 4
# < a²²⁵> = Subgrupo Cíclico generado por 25
# < a²²⁶> = Subgrupo Cíclico generado por 2
# < a²²⁷> = --- Grupo Cíclico de G ---
# < a²²⁸> = Subgrupo Cíclico generado por 4
# < a²²⁹> = --- Grupo Cíclico de G ---
# < a²³⁰> = Subgrupo Cíclico generado por 10
# < a²³¹> = --- Grupo Cíclico de G ---
# < a²³²> = Subgrupo Cíclico generado por 116
# < a²³³> = --- Grupo Cíclico de G ---
# < a²³⁴> = Subgrupo Cíclico generado por 2
# < a²³⁵> = Subgrupo Cíclico generado por 5
# < a²³⁶> = Subgrupo Cíclico generado por 4
# < a²³⁷> = --- Grupo Cíclico de G ---
# < a²³⁸> = Subgrupo Cíclico generado por 2
# < a²³⁹> = --- Grupo Cíclico de G ---
# < a²⁴⁰> = Subgrupo Cíclico generado por 20
# < a²⁴¹> = --- Grupo Cíclico de G ---
# < a²⁴²> = Subgrupo Cíclico generado por 2
# < a²⁴³> = --- Grupo Cíclico de G ---
# < a²⁴⁴> = Subgrupo Cíclico generado por 4
# < a²⁴⁵> = Subgrupo Cíclico generado por 5
# < a²⁴⁶> = Subgrupo Cíclico generado por 2
# < a²⁴⁷> = --- Grupo Cíclico de G ---
# < a²⁴⁸> = Subgrupo Cíclico generado por 4
# < a²⁴⁹> = --- Grupo Cíclico de G ---
# < a²⁵⁰> = Subgrupo Cíclico generado por si MISMO
# < a²⁵¹> = --- Grupo Cíclico de G ---
# < a²⁵²> = Subgrupo Cíclico generado por 4
# < a²⁵³> = --- Grupo Cíclico de G ---
# < a²⁵⁴> = Subgrupo Cíclico generado por 2
# < a²⁵⁵> = Subgrupo Cíclico generado por 5
# < a²⁵⁶> = Subgrupo Cíclico generado por 4
# < a²⁵⁷> = --- Grupo Cíclico de G ---
# < a²⁵⁸> = Subgrupo Cíclico generado por 2
# < a²⁵⁹> = --- Grupo Cíclico de G ---
# < a²⁶⁰> = Subgrupo Cíclico generado por 20
# < a²⁶¹> = Subgrupo Cíclico generado por 29
# < a²⁶²> = Subgrupo Cíclico generado por 2
# < a²⁶³> = --- Grupo Cíclico de G ---
# < a²⁶⁴> = Subgrupo Cíclico generado por 4
# < a²⁶⁵> = Subgrupo Cíclico generado por 5
# < a²⁶⁶> = Subgrupo Cíclico generado por 2
# < a²⁶⁷> = --- Grupo Cíclico de G ---
# < a²⁶⁸> = Subgrupo Cíclico generado por 4
# < a²⁶⁹> = --- Grupo Cíclico de G ---
# < a²⁷⁰> = Subgrupo Cíclico generado por 10
# < a²⁷¹> = --- Grupo Cíclico de G ---
# < a²⁷²> = Subgrupo Cíclico generado por 4
# < a²⁷³> = --- Grupo Cíclico de G ---
# < a²⁷⁴> = Subgrupo Cíclico generado por 2
# < a²⁷⁵> = Subgrupo Cíclico generado por 25
# < a²⁷⁶> = Subgrupo Cíclico generado por 4
# < a²⁷⁷> = --- Grupo Cíclico de G ---
# < a²⁷⁸> = Subgrupo Cíclico generado por 2
# < a²⁷⁹> = --- Grupo Cíclico de G ---
# < a²⁸⁰> = Subgrupo Cíclico generado por 20
# < a²⁸¹> = --- Grupo Cíclico de G ---
# < a²⁸²> = Subgrupo Cíclico generado por 2
# < a²⁸³> = --- Grupo Cíclico de G ---
# < a²⁸⁴> = Subgrupo Cíclico generado por 4
# < a²⁸⁵> = Subgrupo Cíclico generado por 5
# < a²⁸⁶> = Subgrupo Cíclico generado por 2
# < a²⁸⁷> = --- Grupo Cíclico de G ---
# < a²⁸⁸> = Subgrupo Cíclico generado por 4
# < a²⁸⁹> = --- Grupo Cíclico de G ---
# < a²⁹⁰> = Subgrupo Cíclico generado por si MISMO
# < a²⁹¹> = --- Grupo Cíclico de G ---
# < a²⁹²> = Subgrupo Cíclico generado por 4
# < a²⁹³> = --- Grupo Cíclico de G ---
# < a²⁹⁴> = Subgrupo Cíclico generado por 2
# < a²⁹⁵> = Subgrupo Cíclico generado por 5
# < a²⁹⁶> = Subgrupo Cíclico generado por 4
# < a²⁹⁷> = --- Grupo Cíclico de G ---
# < a²⁹⁸> = Subgrupo Cíclico generado por 2
# < a²⁹⁹> = --- Grupo Cíclico de G ---
# < a³⁰⁰> = Subgrupo Cíclico generado por 100
# < a³⁰¹> = --- Grupo Cíclico de G ---
# < a³⁰²> = Subgrupo Cíclico generado por 2
# < a³⁰³> = --- Grupo Cíclico de G ---
# < a³⁰⁴> = Subgrupo Cíclico generado por 4
# < a³⁰⁵> = Subgrupo Cíclico generado por 5
# < a³⁰⁶> = Subgrupo Cíclico generado por 2
# < a³⁰⁷> = --- Grupo Cíclico de G ---
# < a³⁰⁸> = Subgrupo Cíclico generado por 4
# < a³⁰⁹> = --- Grupo Cíclico de G ---
# < a³¹⁰> = Subgrupo Cíclico generado por 10
# < a³¹¹> = --- Grupo Cíclico de G ---
# < a³¹²> = Subgrupo Cíclico generado por 4
# < a³¹³> = --- Grupo Cíclico de G ---
# < a³¹⁴> = Subgrupo Cíclico generado por 2
# < a³¹⁵> = Subgrupo Cíclico generado por 5
# < a³¹⁶> = Subgrupo Cíclico generado por 4
# < a³¹⁷> = --- Grupo Cíclico de G ---
# < a³¹⁸> = Subgrupo Cíclico generado por 2
# < a³¹⁹> = Subgrupo Cíclico generado por 29
# < a³²⁰> = Subgrupo Cíclico generado por 20
# < a³²¹> = --- Grupo Cíclico de G ---
# < a³²²> = Subgrupo Cíclico generado por 2
# < a³²³> = --- Grupo Cíclico de G ---
# < a³²⁴> = Subgrupo Cíclico generado por 4
# < a³²⁵> = Subgrupo Cíclico generado por 25
# < a³²⁶> = Subgrupo Cíclico generado por 2
# < a³²⁷> = --- Grupo Cíclico de G ---
# < a³²⁸> = Subgrupo Cíclico generado por 4
# < a³²⁹> = --- Grupo Cíclico de G ---
# < a³³⁰> = Subgrupo Cíclico generado por 10
# < a³³¹> = --- Grupo Cíclico de G ---
# < a³³²> = Subgrupo Cíclico generado por 4
# < a³³³> = --- Grupo Cíclico de G ---
# < a³³⁴> = Subgrupo Cíclico generado por 2
# < a³³⁵> = Subgrupo Cíclico generado por 5
# < a³³⁶> = Subgrupo Cíclico generado por 4
# < a³³⁷> = --- Grupo Cíclico de G ---
# < a³³⁸> = Subgrupo Cíclico generado por 2
# < a³³⁹> = --- Grupo Cíclico de G ---
# < a³⁴⁰> = Subgrupo Cíclico generado por 20
# < a³⁴¹> = --- Grupo Cíclico de G ---
# < a³⁴²> = Subgrupo Cíclico generado por 2
# < a³⁴³> = --- Grupo Cíclico de G ---
# < a³⁴⁴> = Subgrupo Cíclico generado por 4
# < a³⁴⁵> = Subgrupo Cíclico generado por 5
# < a³⁴⁶> = Subgrupo Cíclico generado por 2
# < a³⁴⁷> = --- Grupo Cíclico de G ---
# < a³⁴⁸> = Subgrupo Cíclico generado por 116
# < a³⁴⁹> = --- Grupo Cíclico de G ---
# < a³⁵⁰> = Subgrupo Cíclico generado por 50
# < a³⁵¹> = --- Grupo Cíclico de G ---
# < a³⁵²> = Subgrupo Cíclico generado por 4
# < a³⁵³> = --- Grupo Cíclico de G ---
# < a³⁵⁴> = Subgrupo Cíclico generado por 2
# < a³⁵⁵> = Subgrupo Cíclico generado por 5
# < a³⁵⁶> = Subgrupo Cíclico generado por 4
# < a³⁵⁷> = --- Grupo Cíclico de G ---
# < a³⁵⁸> = Subgrupo Cíclico generado por 2
# < a³⁵⁹> = --- Grupo Cíclico de G ---
# < a³⁶⁰> = Subgrupo Cíclico generado por 20
# < a³⁶¹> = --- Grupo Cíclico de G ---
# < a³⁶²> = Subgrupo Cíclico generado por 2
# < a³⁶³> = --- Grupo Cíclico de G ---
# < a³⁶⁴> = Subgrupo Cíclico generado por 4
# < a³⁶⁵> = Subgrupo Cíclico generado por 5
# < a³⁶⁶> = Subgrupo Cíclico generado por 2
# < a³⁶⁷> = --- Grupo Cíclico de G ---
# < a³⁶⁸> = Subgrupo Cíclico generado por 4
# < a³⁶⁹> = --- Grupo Cíclico de G ---
# < a³⁷⁰> = Subgrupo Cíclico generado por 10
# < a³⁷¹> = --- Grupo Cíclico de G ---
# < a³⁷²> = Subgrupo Cíclico generado por 4
# < a³⁷³> = --- Grupo Cíclico de G ---
# < a³⁷⁴> = Subgrupo Cíclico generado por 2
# < a³⁷⁵> = Subgrupo Cíclico generado por 125
# < a³⁷⁶> = Subgrupo Cíclico generado por 4
# < a³⁷⁷> = Subgrupo Cíclico generado por 29
# < a³⁷⁸> = Subgrupo Cíclico generado por 2
# < a³⁷⁹> = --- Grupo Cíclico de G ---
# < a³⁸⁰> = Subgrupo Cíclico generado por 20
# < a³⁸¹> = --- Grupo Cíclico de G ---
# < a³⁸²> = Subgrupo Cíclico generado por 2
# < a³⁸³> = --- Grupo Cíclico de G ---
# < a³⁸⁴> = Subgrupo Cíclico generado por 4
# < a³⁸⁵> = Subgrupo Cíclico generado por 5
# < a³⁸⁶> = Subgrupo Cíclico generado por 2
# < a³⁸⁷> = --- Grupo Cíclico de G ---
# < a³⁸⁸> = Subgrupo Cíclico generado por 4
# < a³⁸⁹> = --- Grupo Cíclico de G ---
# < a³⁹⁰> = Subgrupo Cíclico generado por 10
# < a³⁹¹> = --- Grupo Cíclico de G ---
# < a³⁹²> = Subgrupo Cíclico generado por 4
# < a³⁹³> = --- Grupo Cíclico de G ---
# < a³⁹⁴> = Subgrupo Cíclico generado por 2
# < a³⁹⁵> = Subgrupo Cíclico generado por 5
# < a³⁹⁶> = Subgrupo Cíclico generado por 4
# < a³⁹⁷> = --- Grupo Cíclico de G ---
# < a³⁹⁸> = Subgrupo Cíclico generado por 2
# < a³⁹⁹> = --- Grupo Cíclico de G ---
# < a⁴⁰⁰> = Subgrupo Cíclico generado por 100
# < a⁴⁰¹> = --- Grupo Cíclico de G ---
# < a⁴⁰²> = Subgrupo Cíclico generado por 2
# < a⁴⁰³> = --- Grupo Cíclico de G ---
# < a⁴⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁴⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁰⁶> = Subgrupo Cíclico generado por 58
# < a⁴⁰⁷> = --- Grupo Cíclico de G ---
# < a⁴⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁴⁰⁹> = --- Grupo Cíclico de G ---
# < a⁴¹⁰> = Subgrupo Cíclico generado por 10
# < a⁴¹¹> = --- Grupo Cíclico de G ---
# < a⁴¹²> = Subgrupo Cíclico generado por 4
# < a⁴¹³> = --- Grupo Cíclico de G ---
# < a⁴¹⁴> = Subgrupo Cíclico generado por 2
# < a⁴¹⁵> = Subgrupo Cíclico generado por 5
# < a⁴¹⁶> = Subgrupo Cíclico generado por 4
# < a⁴¹⁷> = --- Grupo Cíclico de G ---
# < a⁴¹⁸> = Subgrupo Cíclico generado por 2
# < a⁴¹⁹> = --- Grupo Cíclico de G ---
# < a⁴²⁰> = Subgrupo Cíclico generado por 20
# < a⁴²¹> = --- Grupo Cíclico de G ---
# < a⁴²²> = Subgrupo Cíclico generado por 2
# < a⁴²³> = --- Grupo Cíclico de G ---
# < a⁴²⁴> = Subgrupo Cíclico generado por 4
# < a⁴²⁵> = Subgrupo Cíclico generado por 25
# < a⁴²⁶> = Subgrupo Cíclico generado por 2
# < a⁴²⁷> = --- Grupo Cíclico de G ---
# < a⁴²⁸> = Subgrupo Cíclico generado por 4
# < a⁴²⁹> = --- Grupo Cíclico de G ---
# < a⁴³⁰> = Subgrupo Cíclico generado por 10
# < a⁴³¹> = --- Grupo Cíclico de G ---
# < a⁴³²> = Subgrupo Cíclico generado por 4
# < a⁴³³> = --- Grupo Cíclico de G ---
# < a⁴³⁴> = Subgrupo Cíclico generado por 2
# < a⁴³⁵> = Subgrupo Cíclico generado por 145
# < a⁴³⁶> = Subgrupo Cíclico generado por 4
# < a⁴³⁷> = --- Grupo Cíclico de G ---
# < a⁴³⁸> = Subgrupo Cíclico generado por 2
# < a⁴³⁹> = --- Grupo Cíclico de G ---
# < a⁴⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁴⁴¹> = --- Grupo Cíclico de G ---
# < a⁴⁴²> = Subgrupo Cíclico generado por 2
# < a⁴⁴³> = --- Grupo Cíclico de G ---
# < a⁴⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁴⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁴⁴⁷> = --- Grupo Cíclico de G ---
# < a⁴⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁴⁴⁹> = --- Grupo Cíclico de G ---
# < a⁴⁵⁰> = Subgrupo Cíclico generado por 50
# < a⁴⁵¹> = --- Grupo Cíclico de G ---
# < a⁴⁵²> = Subgrupo Cíclico generado por 4
# < a⁴⁵³> = --- Grupo Cíclico de G ---
# < a⁴⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁴⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁴⁵⁷> = --- Grupo Cíclico de G ---
# < a⁴⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁴⁵⁹> = --- Grupo Cíclico de G ---
# < a⁴⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁴⁶¹> = --- Grupo Cíclico de G ---
# < a⁴⁶²> = Subgrupo Cíclico generado por 2
# < a⁴⁶³> = --- Grupo Cíclico de G ---
# < a⁴⁶⁴> = Subgrupo Cíclico generado por 116
# < a⁴⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁴⁶⁷> = --- Grupo Cíclico de G ---
# < a⁴⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁴⁶⁹> = --- Grupo Cíclico de G ---
# < a⁴⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁴⁷¹> = --- Grupo Cíclico de G ---
# < a⁴⁷²> = Subgrupo Cíclico generado por 4
# < a⁴⁷³> = --- Grupo Cíclico de G ---
# < a⁴⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁴⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁴⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁴⁷⁷> = --- Grupo Cíclico de G ---
# < a⁴⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁴⁷⁹> = --- Grupo Cíclico de G ---
# < a⁴⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁴⁸¹> = --- Grupo Cíclico de G ---
# < a⁴⁸²> = Subgrupo Cíclico generado por 2
# < a⁴⁸³> = --- Grupo Cíclico de G ---
# < a⁴⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁴⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁴⁸⁷> = --- Grupo Cíclico de G ---
# < a⁴⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁴⁸⁹> = --- Grupo Cíclico de G ---
# < a⁴⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁴⁹¹> = --- Grupo Cíclico de G ---
# < a⁴⁹²> = Subgrupo Cíclico generado por 4
# < a⁴⁹³> = Subgrupo Cíclico generado por 29
# < a⁴⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁴⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁴⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁴⁹⁷> = --- Grupo Cíclico de G ---
# < a⁴⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁴⁹⁹> = --- Grupo Cíclico de G ---
# < a⁵⁰⁰> = Subgrupo Cíclico generado por si MISMO
# < a⁵⁰¹> = --- Grupo Cíclico de G ---
# < a⁵⁰²> = Subgrupo Cíclico generado por 2
# < a⁵⁰³> = --- Grupo Cíclico de G ---
# < a⁵⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁵⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁰⁶> = Subgrupo Cíclico generado por 2
# < a⁵⁰⁷> = --- Grupo Cíclico de G ---
# < a⁵⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁵⁰⁹> = --- Grupo Cíclico de G ---
# < a⁵¹⁰> = Subgrupo Cíclico generado por 10
# < a⁵¹¹> = --- Grupo Cíclico de G ---
# < a⁵¹²> = Subgrupo Cíclico generado por 4
# < a⁵¹³> = --- Grupo Cíclico de G ---
# < a⁵¹⁴> = Subgrupo Cíclico generado por 2
# < a⁵¹⁵> = Subgrupo Cíclico generado por 5
# < a⁵¹⁶> = Subgrupo Cíclico generado por 4
# < a⁵¹⁷> = --- Grupo Cíclico de G ---
# < a⁵¹⁸> = Subgrupo Cíclico generado por 2
# < a⁵¹⁹> = --- Grupo Cíclico de G ---
# < a⁵²⁰> = Subgrupo Cíclico generado por 20
# < a⁵²¹> = --- Grupo Cíclico de G ---
# < a⁵²²> = Subgrupo Cíclico generado por 58
# < a⁵²³> = --- Grupo Cíclico de G ---
# < a⁵²⁴> = Subgrupo Cíclico generado por 4
# < a⁵²⁵> = Subgrupo Cíclico generado por 25
# < a⁵²⁶> = Subgrupo Cíclico generado por 2
# < a⁵²⁷> = --- Grupo Cíclico de G ---
# < a⁵²⁸> = Subgrupo Cíclico generado por 4
# < a⁵²⁹> = --- Grupo Cíclico de G ---
# < a⁵³⁰> = Subgrupo Cíclico generado por 10
# < a⁵³¹> = --- Grupo Cíclico de G ---
# < a⁵³²> = Subgrupo Cíclico generado por 4
# < a⁵³³> = --- Grupo Cíclico de G ---
# < a⁵³⁴> = Subgrupo Cíclico generado por 2
# < a⁵³⁵> = Subgrupo Cíclico generado por 5
# < a⁵³⁶> = Subgrupo Cíclico generado por 4
# < a⁵³⁷> = --- Grupo Cíclico de G ---
# < a⁵³⁸> = Subgrupo Cíclico generado por 2
# < a⁵³⁹> = --- Grupo Cíclico de G ---
# < a⁵⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁵⁴¹> = --- Grupo Cíclico de G ---
# < a⁵⁴²> = Subgrupo Cíclico generado por 2
# < a⁵⁴³> = --- Grupo Cíclico de G ---
# < a⁵⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁵⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁵⁴⁷> = --- Grupo Cíclico de G ---
# < a⁵⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁵⁴⁹> = --- Grupo Cíclico de G ---
# < a⁵⁵⁰> = Subgrupo Cíclico generado por 50
# < a⁵⁵¹> = Subgrupo Cíclico generado por 29
# < a⁵⁵²> = Subgrupo Cíclico generado por 4
# < a⁵⁵³> = --- Grupo Cíclico de G ---
# < a⁵⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁵⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁵⁵⁷> = --- Grupo Cíclico de G ---
# < a⁵⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁵⁵⁹> = --- Grupo Cíclico de G ---
# < a⁵⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁵⁶¹> = --- Grupo Cíclico de G ---
# < a⁵⁶²> = Subgrupo Cíclico generado por 2
# < a⁵⁶³> = --- Grupo Cíclico de G ---
# < a⁵⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁵⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁵⁶⁷> = --- Grupo Cíclico de G ---
# < a⁵⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁵⁶⁹> = --- Grupo Cíclico de G ---
# < a⁵⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁵⁷¹> = --- Grupo Cíclico de G ---
# < a⁵⁷²> = Subgrupo Cíclico generado por 4
# < a⁵⁷³> = --- Grupo Cíclico de G ---
# < a⁵⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁵⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁵⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁵⁷⁷> = --- Grupo Cíclico de G ---
# < a⁵⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁵⁷⁹> = --- Grupo Cíclico de G ---
# < a⁵⁸⁰> = Subgrupo Cíclico generado por si MISMO
# < a⁵⁸¹> = --- Grupo Cíclico de G ---
# < a⁵⁸²> = Subgrupo Cíclico generado por 2
# < a⁵⁸³> = --- Grupo Cíclico de G ---
# < a⁵⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁵⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁵⁸⁷> = --- Grupo Cíclico de G ---
# < a⁵⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁵⁸⁹> = --- Grupo Cíclico de G ---
# < a⁵⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁵⁹¹> = --- Grupo Cíclico de G ---
# < a⁵⁹²> = Subgrupo Cíclico generado por 4
# < a⁵⁹³> = --- Grupo Cíclico de G ---
# < a⁵⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁵⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁵⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁵⁹⁷> = --- Grupo Cíclico de G ---
# < a⁵⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁵⁹⁹> = --- Grupo Cíclico de G ---
# < a⁶⁰⁰> = Subgrupo Cíclico generado por 100
# < a⁶⁰¹> = --- Grupo Cíclico de G ---
# < a⁶⁰²> = Subgrupo Cíclico generado por 2
# < a⁶⁰³> = --- Grupo Cíclico de G ---
# < a⁶⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁶⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁰⁶> = Subgrupo Cíclico generado por 2
# < a⁶⁰⁷> = --- Grupo Cíclico de G ---
# < a⁶⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁶⁰⁹> = Subgrupo Cíclico generado por 29
# < a⁶¹⁰> = Subgrupo Cíclico generado por 10
# < a⁶¹¹> = --- Grupo Cíclico de G ---
# < a⁶¹²> = Subgrupo Cíclico generado por 4
# < a⁶¹³> = --- Grupo Cíclico de G ---
# < a⁶¹⁴> = Subgrupo Cíclico generado por 2
# < a⁶¹⁵> = Subgrupo Cíclico generado por 5
# < a⁶¹⁶> = Subgrupo Cíclico generado por 4
# < a⁶¹⁷> = --- Grupo Cíclico de G ---
# < a⁶¹⁸> = Subgrupo Cíclico generado por 2
# < a⁶¹⁹> = --- Grupo Cíclico de G ---
# < a⁶²⁰> = Subgrupo Cíclico generado por 20
# < a⁶²¹> = --- Grupo Cíclico de G ---
# < a⁶²²> = Subgrupo Cíclico generado por 2
# < a⁶²³> = --- Grupo Cíclico de G ---
# < a⁶²⁴> = Subgrupo Cíclico generado por 4
# < a⁶²⁵> = Subgrupo Cíclico generado por 125
# < a⁶²⁶> = Subgrupo Cíclico generado por 2
# < a⁶²⁷> = --- Grupo Cíclico de G ---
# < a⁶²⁸> = Subgrupo Cíclico generado por 4
# < a⁶²⁹> = --- Grupo Cíclico de G ---
# < a⁶³⁰> = Subgrupo Cíclico generado por 10
# < a⁶³¹> = --- Grupo Cíclico de G ---
# < a⁶³²> = Subgrupo Cíclico generado por 4
# < a⁶³³> = --- Grupo Cíclico de G ---
# < a⁶³⁴> = Subgrupo Cíclico generado por 2
# < a⁶³⁵> = Subgrupo Cíclico generado por 5
# < a⁶³⁶> = Subgrupo Cíclico generado por 4
# < a⁶³⁷> = --- Grupo Cíclico de G ---
# < a⁶³⁸> = Subgrupo Cíclico generado por 58
# < a⁶³⁹> = --- Grupo Cíclico de G ---
# < a⁶⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁶⁴¹> = --- Grupo Cíclico de G ---
# < a⁶⁴²> = Subgrupo Cíclico generado por 2
# < a⁶⁴³> = --- Grupo Cíclico de G ---
# < a⁶⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁶⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁶⁴⁷> = --- Grupo Cíclico de G ---
# < a⁶⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁶⁴⁹> = --- Grupo Cíclico de G ---
# < a⁶⁵⁰> = Subgrupo Cíclico generado por 50
# < a⁶⁵¹> = --- Grupo Cíclico de G ---
# < a⁶⁵²> = Subgrupo Cíclico generado por 4
# < a⁶⁵³> = --- Grupo Cíclico de G ---
# < a⁶⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁶⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁶⁵⁷> = --- Grupo Cíclico de G ---
# < a⁶⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁶⁵⁹> = --- Grupo Cíclico de G ---
# < a⁶⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁶⁶¹> = --- Grupo Cíclico de G ---
# < a⁶⁶²> = Subgrupo Cíclico generado por 2
# < a⁶⁶³> = --- Grupo Cíclico de G ---
# < a⁶⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁶⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁶⁶⁷> = Subgrupo Cíclico generado por 29
# < a⁶⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁶⁶⁹> = --- Grupo Cíclico de G ---
# < a⁶⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁶⁷¹> = --- Grupo Cíclico de G ---
# < a⁶⁷²> = Subgrupo Cíclico generado por 4
# < a⁶⁷³> = --- Grupo Cíclico de G ---
# < a⁶⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁶⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁶⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁶⁷⁷> = --- Grupo Cíclico de G ---
# < a⁶⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁶⁷⁹> = --- Grupo Cíclico de G ---
# < a⁶⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁶⁸¹> = --- Grupo Cíclico de G ---
# < a⁶⁸²> = Subgrupo Cíclico generado por 2
# < a⁶⁸³> = --- Grupo Cíclico de G ---
# < a⁶⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁶⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁶⁸⁷> = --- Grupo Cíclico de G ---
# < a⁶⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁶⁸⁹> = --- Grupo Cíclico de G ---
# < a⁶⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁶⁹¹> = --- Grupo Cíclico de G ---
# < a⁶⁹²> = Subgrupo Cíclico generado por 4
# < a⁶⁹³> = --- Grupo Cíclico de G ---
# < a⁶⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁶⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁶⁹⁶> = Subgrupo Cíclico generado por 116
# < a⁶⁹⁷> = --- Grupo Cíclico de G ---
# < a⁶⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁶⁹⁹> = --- Grupo Cíclico de G ---
# < a⁷⁰⁰> = Subgrupo Cíclico generado por 100
# < a⁷⁰¹> = --- Grupo Cíclico de G ---
# < a⁷⁰²> = Subgrupo Cíclico generado por 2
# < a⁷⁰³> = --- Grupo Cíclico de G ---
# < a⁷⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁷⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁰⁶> = Subgrupo Cíclico generado por 2
# < a⁷⁰⁷> = --- Grupo Cíclico de G ---
# < a⁷⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁷⁰⁹> = --- Grupo Cíclico de G ---
# < a⁷¹⁰> = Subgrupo Cíclico generado por 10
# < a⁷¹¹> = --- Grupo Cíclico de G ---
# < a⁷¹²> = Subgrupo Cíclico generado por 4
# < a⁷¹³> = --- Grupo Cíclico de G ---
# < a⁷¹⁴> = Subgrupo Cíclico generado por 2
# < a⁷¹⁵> = Subgrupo Cíclico generado por 5
# < a⁷¹⁶> = Subgrupo Cíclico generado por 4
# < a⁷¹⁷> = --- Grupo Cíclico de G ---
# < a⁷¹⁸> = Subgrupo Cíclico generado por 2
# < a⁷¹⁹> = --- Grupo Cíclico de G ---
# < a⁷²⁰> = Subgrupo Cíclico generado por 20
# < a⁷²¹> = --- Grupo Cíclico de G ---
# < a⁷²²> = Subgrupo Cíclico generado por 2
# < a⁷²³> = --- Grupo Cíclico de G ---
# < a⁷²⁴> = Subgrupo Cíclico generado por 4
# < a⁷²⁵> = Subgrupo Cíclico generado por si MISMO
# < a⁷²⁶> = Subgrupo Cíclico generado por 2
# < a⁷²⁷> = --- Grupo Cíclico de G ---
# < a⁷²⁸> = Subgrupo Cíclico generado por 4
# < a⁷²⁹> = --- Grupo Cíclico de G ---
# < a⁷³⁰> = Subgrupo Cíclico generado por 10
# < a⁷³¹> = --- Grupo Cíclico de G ---
# < a⁷³²> = Subgrupo Cíclico generado por 4
# < a⁷³³> = --- Grupo Cíclico de G ---
# < a⁷³⁴> = Subgrupo Cíclico generado por 2
# < a⁷³⁵> = Subgrupo Cíclico generado por 5
# < a⁷³⁶> = Subgrupo Cíclico generado por 4
# < a⁷³⁷> = --- Grupo Cíclico de G ---
# < a⁷³⁸> = Subgrupo Cíclico generado por 2
# < a⁷³⁹> = --- Grupo Cíclico de G ---
# < a⁷⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁷⁴¹> = --- Grupo Cíclico de G ---
# < a⁷⁴²> = Subgrupo Cíclico generado por 2
# < a⁷⁴³> = --- Grupo Cíclico de G ---
# < a⁷⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁷⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁷⁴⁷> = --- Grupo Cíclico de G ---
# < a⁷⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁷⁴⁹> = --- Grupo Cíclico de G ---
# < a⁷⁵⁰> = Subgrupo Cíclico generado por 250
# < a⁷⁵¹> = --- Grupo Cíclico de G ---
# < a⁷⁵²> = Subgrupo Cíclico generado por 4
# < a⁷⁵³> = --- Grupo Cíclico de G ---
# < a⁷⁵⁴> = Subgrupo Cíclico generado por 58
# < a⁷⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁷⁵⁷> = --- Grupo Cíclico de G ---
# < a⁷⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁷⁵⁹> = --- Grupo Cíclico de G ---
# < a⁷⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁷⁶¹> = --- Grupo Cíclico de G ---
# < a⁷⁶²> = Subgrupo Cíclico generado por 2
# < a⁷⁶³> = --- Grupo Cíclico de G ---
# < a⁷⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁷⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁷⁶⁷> = --- Grupo Cíclico de G ---
# < a⁷⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁷⁶⁹> = --- Grupo Cíclico de G ---
# < a⁷⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁷⁷¹> = --- Grupo Cíclico de G ---
# < a⁷⁷²> = Subgrupo Cíclico generado por 4
# < a⁷⁷³> = --- Grupo Cíclico de G ---
# < a⁷⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁷⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁷⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁷⁷⁷> = --- Grupo Cíclico de G ---
# < a⁷⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁷⁷⁹> = --- Grupo Cíclico de G ---
# < a⁷⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁷⁸¹> = --- Grupo Cíclico de G ---
# < a⁷⁸²> = Subgrupo Cíclico generado por 2
# < a⁷⁸³> = Subgrupo Cíclico generado por 29
# < a⁷⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁷⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁷⁸⁷> = --- Grupo Cíclico de G ---
# < a⁷⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁷⁸⁹> = --- Grupo Cíclico de G ---
# < a⁷⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁷⁹¹> = --- Grupo Cíclico de G ---
# < a⁷⁹²> = Subgrupo Cíclico generado por 4
# < a⁷⁹³> = --- Grupo Cíclico de G ---
# < a⁷⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁷⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁷⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁷⁹⁷> = --- Grupo Cíclico de G ---
# < a⁷⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁷⁹⁹> = --- Grupo Cíclico de G ---
# < a⁸⁰⁰> = Subgrupo Cíclico generado por 100
# < a⁸⁰¹> = --- Grupo Cíclico de G ---
# < a⁸⁰²> = Subgrupo Cíclico generado por 2
# < a⁸⁰³> = --- Grupo Cíclico de G ---
# < a⁸⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁸⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁰⁶> = Subgrupo Cíclico generado por 2
# < a⁸⁰⁷> = --- Grupo Cíclico de G ---
# < a⁸⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁸⁰⁹> = --- Grupo Cíclico de G ---
# < a⁸¹⁰> = Subgrupo Cíclico generado por 10
# < a⁸¹¹> = --- Grupo Cíclico de G ---
# < a⁸¹²> = Subgrupo Cíclico generado por 116
# < a⁸¹³> = --- Grupo Cíclico de G ---
# < a⁸¹⁴> = Subgrupo Cíclico generado por 2
# < a⁸¹⁵> = Subgrupo Cíclico generado por 5
# < a⁸¹⁶> = Subgrupo Cíclico generado por 4
# < a⁸¹⁷> = --- Grupo Cíclico de G ---
# < a⁸¹⁸> = Subgrupo Cíclico generado por 2
# < a⁸¹⁹> = --- Grupo Cíclico de G ---
# < a⁸²⁰> = Subgrupo Cíclico generado por 20
# < a⁸²¹> = --- Grupo Cíclico de G ---
# < a⁸²²> = Subgrupo Cíclico generado por 2
# < a⁸²³> = --- Grupo Cíclico de G ---
# < a⁸²⁴> = Subgrupo Cíclico generado por 4
# < a⁸²⁵> = Subgrupo Cíclico generado por 25
# < a⁸²⁶> = Subgrupo Cíclico generado por 2
# < a⁸²⁷> = --- Grupo Cíclico de G ---
# < a⁸²⁸> = Subgrupo Cíclico generado por 4
# < a⁸²⁹> = --- Grupo Cíclico de G ---
# < a⁸³⁰> = Subgrupo Cíclico generado por 10
# < a⁸³¹> = --- Grupo Cíclico de G ---
# < a⁸³²> = Subgrupo Cíclico generado por 4
# < a⁸³³> = --- Grupo Cíclico de G ---
# < a⁸³⁴> = Subgrupo Cíclico generado por 2
# < a⁸³⁵> = Subgrupo Cíclico generado por 5
# < a⁸³⁶> = Subgrupo Cíclico generado por 4
# < a⁸³⁷> = --- Grupo Cíclico de G ---
# < a⁸³⁸> = Subgrupo Cíclico generado por 2
# < a⁸³⁹> = --- Grupo Cíclico de G ---
# < a⁸⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁸⁴¹> = Subgrupo Cíclico generado por 29
# < a⁸⁴²> = Subgrupo Cíclico generado por 2
# < a⁸⁴³> = --- Grupo Cíclico de G ---
# < a⁸⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁸⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁸⁴⁷> = --- Grupo Cíclico de G ---
# < a⁸⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁸⁴⁹> = --- Grupo Cíclico de G ---
# < a⁸⁵⁰> = Subgrupo Cíclico generado por 50
# < a⁸⁵¹> = --- Grupo Cíclico de G ---
# < a⁸⁵²> = Subgrupo Cíclico generado por 4
# < a⁸⁵³> = --- Grupo Cíclico de G ---
# < a⁸⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁸⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁸⁵⁷> = --- Grupo Cíclico de G ---
# < a⁸⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁸⁵⁹> = --- Grupo Cíclico de G ---
# < a⁸⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁸⁶¹> = --- Grupo Cíclico de G ---
# < a⁸⁶²> = Subgrupo Cíclico generado por 2
# < a⁸⁶³> = --- Grupo Cíclico de G ---
# < a⁸⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁸⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁸⁶⁷> = --- Grupo Cíclico de G ---
# < a⁸⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁸⁶⁹> = --- Grupo Cíclico de G ---
# < a⁸⁷⁰> = Subgrupo Cíclico generado por 290
# < a⁸⁷¹> = --- Grupo Cíclico de G ---
# < a⁸⁷²> = Subgrupo Cíclico generado por 4
# < a⁸⁷³> = --- Grupo Cíclico de G ---
# < a⁸⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁸⁷⁵> = Subgrupo Cíclico generado por 125
# < a⁸⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁸⁷⁷> = --- Grupo Cíclico de G ---
# < a⁸⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁸⁷⁹> = --- Grupo Cíclico de G ---
# < a⁸⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁸⁸¹> = --- Grupo Cíclico de G ---
# < a⁸⁸²> = Subgrupo Cíclico generado por 2
# < a⁸⁸³> = --- Grupo Cíclico de G ---
# < a⁸⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁸⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁸⁶> = Subgrupo Cíclico generado por 2
# < a⁸⁸⁷> = --- Grupo Cíclico de G ---
# < a⁸⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁸⁸⁹> = --- Grupo Cíclico de G ---
# < a⁸⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁸⁹¹> = --- Grupo Cíclico de G ---
# < a⁸⁹²> = Subgrupo Cíclico generado por 4
# < a⁸⁹³> = --- Grupo Cíclico de G ---
# < a⁸⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁸⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁸⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁸⁹⁷> = --- Grupo Cíclico de G ---
# < a⁸⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁸⁹⁹> = Subgrupo Cíclico generado por 29
# < a⁹⁰⁰> = Subgrupo Cíclico generado por 100
# < a⁹⁰¹> = --- Grupo Cíclico de G ---
# < a⁹⁰²> = Subgrupo Cíclico generado por 2
# < a⁹⁰³> = --- Grupo Cíclico de G ---
# < a⁹⁰⁴> = Subgrupo Cíclico generado por 4
# < a⁹⁰⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁰⁶> = Subgrupo Cíclico generado por 2
# < a⁹⁰⁷> = --- Grupo Cíclico de G ---
# < a⁹⁰⁸> = Subgrupo Cíclico generado por 4
# < a⁹⁰⁹> = --- Grupo Cíclico de G ---
# < a⁹¹⁰> = Subgrupo Cíclico generado por 10
# < a⁹¹¹> = --- Grupo Cíclico de G ---
# < a⁹¹²> = Subgrupo Cíclico generado por 4
# < a⁹¹³> = --- Grupo Cíclico de G ---
# < a⁹¹⁴> = Subgrupo Cíclico generado por 2
# < a⁹¹⁵> = Subgrupo Cíclico generado por 5
# < a⁹¹⁶> = Subgrupo Cíclico generado por 4
# < a⁹¹⁷> = --- Grupo Cíclico de G ---
# < a⁹¹⁸> = Subgrupo Cíclico generado por 2
# < a⁹¹⁹> = --- Grupo Cíclico de G ---
# < a⁹²⁰> = Subgrupo Cíclico generado por 20
# < a⁹²¹> = --- Grupo Cíclico de G ---
# < a⁹²²> = Subgrupo Cíclico generado por 2
# < a⁹²³> = --- Grupo Cíclico de G ---
# < a⁹²⁴> = Subgrupo Cíclico generado por 4
# < a⁹²⁵> = Subgrupo Cíclico generado por 25
# < a⁹²⁶> = Subgrupo Cíclico generado por 2
# < a⁹²⁷> = --- Grupo Cíclico de G ---
# < a⁹²⁸> = Subgrupo Cíclico generado por 116
# < a⁹²⁹> = --- Grupo Cíclico de G ---
# < a⁹³⁰> = Subgrupo Cíclico generado por 10
# < a⁹³¹> = --- Grupo Cíclico de G ---
# < a⁹³²> = Subgrupo Cíclico generado por 4
# < a⁹³³> = --- Grupo Cíclico de G ---
# < a⁹³⁴> = Subgrupo Cíclico generado por 2
# < a⁹³⁵> = Subgrupo Cíclico generado por 5
# < a⁹³⁶> = Subgrupo Cíclico generado por 4
# < a⁹³⁷> = --- Grupo Cíclico de G ---
# < a⁹³⁸> = Subgrupo Cíclico generado por 2
# < a⁹³⁹> = --- Grupo Cíclico de G ---
# < a⁹⁴⁰> = Subgrupo Cíclico generado por 20
# < a⁹⁴¹> = --- Grupo Cíclico de G ---
# < a⁹⁴²> = Subgrupo Cíclico generado por 2
# < a⁹⁴³> = --- Grupo Cíclico de G ---
# < a⁹⁴⁴> = Subgrupo Cíclico generado por 4
# < a⁹⁴⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁴⁶> = Subgrupo Cíclico generado por 2
# < a⁹⁴⁷> = --- Grupo Cíclico de G ---
# < a⁹⁴⁸> = Subgrupo Cíclico generado por 4
# < a⁹⁴⁹> = --- Grupo Cíclico de G ---
# < a⁹⁵⁰> = Subgrupo Cíclico generado por 50
# < a⁹⁵¹> = --- Grupo Cíclico de G ---
# < a⁹⁵²> = Subgrupo Cíclico generado por 4
# < a⁹⁵³> = --- Grupo Cíclico de G ---
# < a⁹⁵⁴> = Subgrupo Cíclico generado por 2
# < a⁹⁵⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁵⁶> = Subgrupo Cíclico generado por 4
# < a⁹⁵⁷> = Subgrupo Cíclico generado por 29
# < a⁹⁵⁸> = Subgrupo Cíclico generado por 2
# < a⁹⁵⁹> = --- Grupo Cíclico de G ---
# < a⁹⁶⁰> = Subgrupo Cíclico generado por 20
# < a⁹⁶¹> = --- Grupo Cíclico de G ---
# < a⁹⁶²> = Subgrupo Cíclico generado por 2
# < a⁹⁶³> = --- Grupo Cíclico de G ---
# < a⁹⁶⁴> = Subgrupo Cíclico generado por 4
# < a⁹⁶⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁶⁶> = Subgrupo Cíclico generado por 2
# < a⁹⁶⁷> = --- Grupo Cíclico de G ---
# < a⁹⁶⁸> = Subgrupo Cíclico generado por 4
# < a⁹⁶⁹> = --- Grupo Cíclico de G ---
# < a⁹⁷⁰> = Subgrupo Cíclico generado por 10
# < a⁹⁷¹> = --- Grupo Cíclico de G ---
# < a⁹⁷²> = Subgrupo Cíclico generado por 4
# < a⁹⁷³> = --- Grupo Cíclico de G ---
# < a⁹⁷⁴> = Subgrupo Cíclico generado por 2
# < a⁹⁷⁵> = Subgrupo Cíclico generado por 25
# < a⁹⁷⁶> = Subgrupo Cíclico generado por 4
# < a⁹⁷⁷> = --- Grupo Cíclico de G ---
# < a⁹⁷⁸> = Subgrupo Cíclico generado por 2
# < a⁹⁷⁹> = --- Grupo Cíclico de G ---
# < a⁹⁸⁰> = Subgrupo Cíclico generado por 20
# < a⁹⁸¹> = --- Grupo Cíclico de G ---
# < a⁹⁸²> = Subgrupo Cíclico generado por 2
# < a⁹⁸³> = --- Grupo Cíclico de G ---
# < a⁹⁸⁴> = Subgrupo Cíclico generado por 4
# < a⁹⁸⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁸⁶> = Subgrupo Cíclico generado por 58
# < a⁹⁸⁷> = --- Grupo Cíclico de G ---
# < a⁹⁸⁸> = Subgrupo Cíclico generado por 4
# < a⁹⁸⁹> = --- Grupo Cíclico de G ---
# < a⁹⁹⁰> = Subgrupo Cíclico generado por 10
# < a⁹⁹¹> = --- Grupo Cíclico de G ---
# < a⁹⁹²> = Subgrupo Cíclico generado por 4
# < a⁹⁹³> = --- Grupo Cíclico de G ---
# < a⁹⁹⁴> = Subgrupo Cíclico generado por 2
# < a⁹⁹⁵> = Subgrupo Cíclico generado por 5
# < a⁹⁹⁶> = Subgrupo Cíclico generado por 4
# < a⁹⁹⁷> = --- Grupo Cíclico de G ---
# < a⁹⁹⁸> = Subgrupo Cíclico generado por 2
# < a⁹⁹⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁰⁰> = Subgrupo Cíclico generado por 500
# < a¹⁰⁰¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁰²> = Subgrupo Cíclico generado por 2
# < a¹⁰⁰³> = --- Grupo Cíclico de G ---
# < a¹⁰⁰⁴> = Subgrupo Cíclico generado por 4
# < a¹⁰⁰⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁰⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰⁰⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁰⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰⁰⁹> = --- Grupo Cíclico de G ---
# < a¹⁰¹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁰¹¹> = --- Grupo Cíclico de G ---
# < a¹⁰¹²> = Subgrupo Cíclico generado por 4
# < a¹⁰¹³> = --- Grupo Cíclico de G ---
# < a¹⁰¹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁰¹⁵> = Subgrupo Cíclico generado por 145
# < a¹⁰¹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁰¹⁷> = --- Grupo Cíclico de G ---
# < a¹⁰¹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁰¹⁹> = --- Grupo Cíclico de G ---
# < a¹⁰²⁰> = Subgrupo Cíclico generado por 20
# < a¹⁰²¹> = --- Grupo Cíclico de G ---
# < a¹⁰²²> = Subgrupo Cíclico generado por 2
# < a¹⁰²³> = --- Grupo Cíclico de G ---
# < a¹⁰²⁴> = Subgrupo Cíclico generado por 4
# < a¹⁰²⁵> = Subgrupo Cíclico generado por 25
# < a¹⁰²⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰²⁷> = --- Grupo Cíclico de G ---
# < a¹⁰²⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰²⁹> = --- Grupo Cíclico de G ---
# < a¹⁰³⁰> = Subgrupo Cíclico generado por 10
# < a¹⁰³¹> = --- Grupo Cíclico de G ---
# < a¹⁰³²> = Subgrupo Cíclico generado por 4
# < a¹⁰³³> = --- Grupo Cíclico de G ---
# < a¹⁰³⁴> = Subgrupo Cíclico generado por 2
# < a¹⁰³⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰³⁶> = Subgrupo Cíclico generado por 4
# < a¹⁰³⁷> = --- Grupo Cíclico de G ---
# < a¹⁰³⁸> = Subgrupo Cíclico generado por 2
# < a¹⁰³⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹⁰⁴¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁴²> = Subgrupo Cíclico generado por 2
# < a¹⁰⁴³> = --- Grupo Cíclico de G ---
# < a¹⁰⁴⁴> = Subgrupo Cíclico generado por 116
# < a¹⁰⁴⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰⁴⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰⁴⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁵⁰> = Subgrupo Cíclico generado por 50
# < a¹⁰⁵¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁵²> = Subgrupo Cíclico generado por 4
# < a¹⁰⁵³> = --- Grupo Cíclico de G ---
# < a¹⁰⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹⁰⁵⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹⁰⁵⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹⁰⁵⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁶⁰> = Subgrupo Cíclico generado por 20
# < a¹⁰⁶¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁶²> = Subgrupo Cíclico generado por 2
# < a¹⁰⁶³> = --- Grupo Cíclico de G ---
# < a¹⁰⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹⁰⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰⁶⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁶⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰⁶⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹⁰⁷¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁷²> = Subgrupo Cíclico generado por 4
# < a¹⁰⁷³> = Subgrupo Cíclico generado por 29
# < a¹⁰⁷⁴> = Subgrupo Cíclico generado por 2
# < a¹⁰⁷⁵> = Subgrupo Cíclico generado por 25
# < a¹⁰⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹⁰⁷⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹⁰⁷⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹⁰⁸¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁸²> = Subgrupo Cíclico generado por 2
# < a¹⁰⁸³> = --- Grupo Cíclico de G ---
# < a¹⁰⁸⁴> = Subgrupo Cíclico generado por 4
# < a¹⁰⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹⁰⁸⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁸⁸> = Subgrupo Cíclico generado por 4
# < a¹⁰⁸⁹> = --- Grupo Cíclico de G ---
# < a¹⁰⁹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁰⁹¹> = --- Grupo Cíclico de G ---
# < a¹⁰⁹²> = Subgrupo Cíclico generado por 4
# < a¹⁰⁹³> = --- Grupo Cíclico de G ---
# < a¹⁰⁹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁰⁹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁰⁹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁰⁹⁷> = --- Grupo Cíclico de G ---
# < a¹⁰⁹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁰⁹⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁰⁰> = Subgrupo Cíclico generado por 100
# < a¹¹⁰¹> = --- Grupo Cíclico de G ---
# < a¹¹⁰²> = Subgrupo Cíclico generado por 58
# < a¹¹⁰³> = --- Grupo Cíclico de G ---
# < a¹¹⁰⁴> = Subgrupo Cíclico generado por 4
# < a¹¹⁰⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁰⁶> = Subgrupo Cíclico generado por 2
# < a¹¹⁰⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁰⁸> = Subgrupo Cíclico generado por 4
# < a¹¹⁰⁹> = --- Grupo Cíclico de G ---
# < a¹¹¹⁰> = Subgrupo Cíclico generado por 10
# < a¹¹¹¹> = --- Grupo Cíclico de G ---
# < a¹¹¹²> = Subgrupo Cíclico generado por 4
# < a¹¹¹³> = --- Grupo Cíclico de G ---
# < a¹¹¹⁴> = Subgrupo Cíclico generado por 2
# < a¹¹¹⁵> = Subgrupo Cíclico generado por 5
# < a¹¹¹⁶> = Subgrupo Cíclico generado por 4
# < a¹¹¹⁷> = --- Grupo Cíclico de G ---
# < a¹¹¹⁸> = Subgrupo Cíclico generado por 2
# < a¹¹¹⁹> = --- Grupo Cíclico de G ---
# < a¹¹²⁰> = Subgrupo Cíclico generado por 20
# < a¹¹²¹> = --- Grupo Cíclico de G ---
# < a¹¹²²> = Subgrupo Cíclico generado por 2
# < a¹¹²³> = --- Grupo Cíclico de G ---
# < a¹¹²⁴> = Subgrupo Cíclico generado por 4
# < a¹¹²⁵> = Subgrupo Cíclico generado por 125
# < a¹¹²⁶> = Subgrupo Cíclico generado por 2
# < a¹¹²⁷> = --- Grupo Cíclico de G ---
# < a¹¹²⁸> = Subgrupo Cíclico generado por 4
# < a¹¹²⁹> = --- Grupo Cíclico de G ---
# < a¹¹³⁰> = Subgrupo Cíclico generado por 10
# < a¹¹³¹> = Subgrupo Cíclico generado por 29
# < a¹¹³²> = Subgrupo Cíclico generado por 4
# < a¹¹³³> = --- Grupo Cíclico de G ---
# < a¹¹³⁴> = Subgrupo Cíclico generado por 2
# < a¹¹³⁵> = Subgrupo Cíclico generado por 5
# < a¹¹³⁶> = Subgrupo Cíclico generado por 4
# < a¹¹³⁷> = --- Grupo Cíclico de G ---
# < a¹¹³⁸> = Subgrupo Cíclico generado por 2
# < a¹¹³⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹¹⁴¹> = --- Grupo Cíclico de G ---
# < a¹¹⁴²> = Subgrupo Cíclico generado por 2
# < a¹¹⁴³> = --- Grupo Cíclico de G ---
# < a¹¹⁴⁴> = Subgrupo Cíclico generado por 4
# < a¹¹⁴⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹¹⁴⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹¹⁴⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁵⁰> = Subgrupo Cíclico generado por 50
# < a¹¹⁵¹> = --- Grupo Cíclico de G ---
# < a¹¹⁵²> = Subgrupo Cíclico generado por 4
# < a¹¹⁵³> = --- Grupo Cíclico de G ---
# < a¹¹⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹¹⁵⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹¹⁵⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹¹⁵⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁶⁰> = Subgrupo Cíclico generado por 580
# < a¹¹⁶¹> = --- Grupo Cíclico de G ---
# < a¹¹⁶²> = Subgrupo Cíclico generado por 2
# < a¹¹⁶³> = --- Grupo Cíclico de G ---
# < a¹¹⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹¹⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹¹⁶⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁶⁸> = Subgrupo Cíclico generado por 4
# < a¹¹⁶⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹¹⁷¹> = --- Grupo Cíclico de G ---
# < a¹¹⁷²> = Subgrupo Cíclico generado por 4
# < a¹¹⁷³> = --- Grupo Cíclico de G ---
# < a¹¹⁷⁴> = Subgrupo Cíclico generado por 2
# < a¹¹⁷⁵> = Subgrupo Cíclico generado por 25
# < a¹¹⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹¹⁷⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹¹⁷⁹> = --- Grupo Cíclico de G ---
# < a¹¹⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹¹⁸¹> = --- Grupo Cíclico de G ---
# < a¹¹⁸²> = Subgrupo Cíclico generado por 2
# < a¹¹⁸³> = --- Grupo Cíclico de G ---
# < a¹¹⁸⁴> = Subgrupo Cíclico generado por 4
# < a¹¹⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹¹⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹¹⁸⁷> = --- Grupo Cíclico de G ---
# < a¹¹⁸⁸> = Subgrupo Cíclico generado por 4
# ...
# < a¹⁴²²⁵> = Subgrupo Cíclico generado por 25
# < a¹⁴²²⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴²²⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²²⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴²²⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²³⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴²³¹> = --- Grupo Cíclico de G ---
# < a¹⁴²³²> = Subgrupo Cíclico generado por 4
# < a¹⁴²³³> = --- Grupo Cíclico de G ---
# < a¹⁴²³⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴²³⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²³⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴²³⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²³⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴²³⁹> = Subgrupo Cíclico generado por 29
# < a¹⁴²⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴²⁴¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁴²> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁴³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁴⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁴⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁴⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁴⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁵⁰> = Subgrupo Cíclico generado por 250
# < a¹⁴²⁵¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁵²> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁵³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁵⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁵⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁵⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁶⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴²⁶¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁶²> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁶³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁶⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²⁶⁸> = Subgrupo Cíclico generado por 116
# < a¹⁴²⁶⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴²⁷¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁷²> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁷³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁷⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁷⁵> = Subgrupo Cíclico generado por 25
# < a¹⁴²⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁷⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁷⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴²⁸¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁸²> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁸³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁸⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁸⁷> = --- Grupo Cíclico de G ---
# < a¹⁴²⁸⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁸⁹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴²⁹¹> = --- Grupo Cíclico de G ---
# < a¹⁴²⁹²> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁹³> = --- Grupo Cíclico de G ---
# < a¹⁴²⁹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴²⁹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴²⁹⁷> = Subgrupo Cíclico generado por 29
# < a¹⁴²⁹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴²⁹⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁰⁰> = Subgrupo Cíclico generado por 100
# < a¹⁴³⁰¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁰²> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁰³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁰⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁰⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³⁰⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁰⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁰⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁰⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³¹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴³¹¹> = --- Grupo Cíclico de G ---
# < a¹⁴³¹²> = Subgrupo Cíclico generado por 4
# < a¹⁴³¹³> = --- Grupo Cíclico de G ---
# < a¹⁴³¹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴³¹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³¹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴³¹⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³¹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴³¹⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³²⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴³²¹> = --- Grupo Cíclico de G ---
# < a¹⁴³²²> = Subgrupo Cíclico generado por 2
# < a¹⁴³²³> = --- Grupo Cíclico de G ---
# < a¹⁴³²⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴³²⁵> = Subgrupo Cíclico generado por 25
# < a¹⁴³²⁶> = Subgrupo Cíclico generado por 58
# < a¹⁴³²⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³²⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴³²⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³³⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴³³¹> = --- Grupo Cíclico de G ---
# < a¹⁴³³²> = Subgrupo Cíclico generado por 4
# < a¹⁴³³³> = --- Grupo Cíclico de G ---
# < a¹⁴³³⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴³³⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³³⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴³³⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³³⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴³³⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴³⁴¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁴²> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁴³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁴⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁴⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁴⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁴⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁵⁰> = Subgrupo Cíclico generado por 50
# < a¹⁴³⁵¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁵²> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁵³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁵⁵> = Subgrupo Cíclico generado por 145
# < a¹⁴³⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁵⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁵⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁶⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴³⁶¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁶²> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁶³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁶⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁶⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁶⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴³⁷¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁷²> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁷³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁷⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁷⁵> = Subgrupo Cíclico generado por 125
# < a¹⁴³⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁷⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁷⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴³⁸¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁸²> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁸³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁸⁴> = Subgrupo Cíclico generado por 116
# < a¹⁴³⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁸⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁸⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁸⁹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴³⁹¹> = --- Grupo Cíclico de G ---
# < a¹⁴³⁹²> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁹³> = --- Grupo Cíclico de G ---
# < a¹⁴³⁹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴³⁹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴³⁹⁷> = --- Grupo Cíclico de G ---
# < a¹⁴³⁹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴³⁹⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁰⁰> = Subgrupo Cíclico generado por 100
# < a¹⁴⁴⁰¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁰²> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁰³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁰⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁰⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁰⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁰⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁰⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁰⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴¹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴⁴¹¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴¹²> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴¹³> = Subgrupo Cíclico generado por 29
# < a¹⁴⁴¹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴¹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴¹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴¹⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴¹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴¹⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴²⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴⁴²¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴²²> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴²³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴²⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴²⁵> = Subgrupo Cíclico generado por 25
# < a¹⁴⁴²⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴²⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴²⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴²⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴³⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴⁴³¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴³²> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴³³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴³⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴³⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴³⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴³⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴³⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴³⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁴⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴⁴⁴¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁴²> = Subgrupo Cíclico generado por 58
# < a¹⁴⁴⁴³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁴⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁴⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁴⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁴⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁴⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁴⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁵⁰> = Subgrupo Cíclico generado por 50
# < a¹⁴⁴⁵¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁵²> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁵³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁵⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁵⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁵⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁵⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁵⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁵⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁶⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴⁴⁶¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁶²> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁶³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁶⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁶⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁶⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁶⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁶⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁶⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁷⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴⁴⁷¹> = Subgrupo Cíclico generado por 29
# < a¹⁴⁴⁷²> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁷³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁷⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁷⁵> = Subgrupo Cíclico generado por 25
# < a¹⁴⁴⁷⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁷⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁷⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁷⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁸⁰> = Subgrupo Cíclico generado por 20
# < a¹⁴⁴⁸¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁸²> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁸³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁸⁴> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁸⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁸⁶> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁸⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁸⁸> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁸⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁹⁰> = Subgrupo Cíclico generado por 10
# < a¹⁴⁴⁹¹> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁹²> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁹³> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁹⁴> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁹⁵> = Subgrupo Cíclico generado por 5
# < a¹⁴⁴⁹⁶> = Subgrupo Cíclico generado por 4
# < a¹⁴⁴⁹⁷> = --- Grupo Cíclico de G ---
# < a¹⁴⁴⁹⁸> = Subgrupo Cíclico generado por 2
# < a¹⁴⁴⁹⁹> = --- Grupo Cíclico de G ---
# < a¹⁴⁵⁰⁰> = Subgrupo Cíclico generado por si MISMO
#                                    Orden del Grupo G: 14500
#
# → Generadores Cíclicos de G:
# | { 1, 3, 7, 9, 11, 13, 17, 19, 21, 23, 27, 31, 33, 37, 39, 41, 43, 47, 49, 51, 53, 57, 59, 61, 63, 67, 69, 71, 73, 77, 79, 81, 83, 89, 91, 93, 97, 99, 101, 103, 107, 109, 111, 113, 117, 119, 121, 123, 127, 129, 131, 133, 137, 139, 141, 143, 147, 149, 151, 153, 157, 159, 161, 163, 167, 169, 171, 173, 177, 179, 181, 183, 187, 189, 191, 193, 197, 199, 201, 207, 209, 211, 213, 217, 219, 221, 223, 227, 229, 231, 233, 237, 239, 241, 243, 247, 249, 251, 253, 257, 259, 263, 267, 269, 271, 273, 277, 279, 281, 283, 287, 289, 291, 293, 297, 299, 301, 303, 307, 309, 311, 313, 317, 321, 323, 327, 329, 331, 333, 337, 339, 341, 343, 347, 349, 351, 353, 357, 359, 361, 363, 367, 369, 371, 373, 379, 381, 383, 387, 389, 391, 393, 397, 399, 401, 403, 407, 409, 411, 413, 417, 419, 421, 423, 427, 429, 431, 433, 437, 439, 441, 443, 447, 449, 451, 453, 457, 459, 461, 463, 467, 469, 471, 473, 477, 479, 481, 483, 487, 489, 491, 497, 499, 501, 503, 507, 509, 511, 513, 517, 519, 521, 523, 527, 529, 531, 533, 537, 539, 541, 543, 547, 549, 553, 557, 559, 561, 563, 567, 569, 571, 573, 577, 579, 581, 583, 587, 589, 591, 593, 597, 599, 601, 603, 607, 611, 613, 617, 619, 621, 623, 627, 629, 631, 633, 637, 639, 641, 643, 647, 649, 651, 653, 657, 659, 661, 663, 669, 671, 673, 677, 679, 681, 683, 687, 689, 691, 693, 697, 699, 701, 703, 707, 709, 711, 713, 717, 719, 721, 723, 727, 729, 731, 733, 737, 739, 741, 743, 747, 749, 751, 753, 757, 759, 761, 763, 767, 769, 771, 773, 777, 779, 781, 787, 789, 791, 793, 797, 799, 801, 803, 807, 809, 811, 813, 817, 819, 821, 823, 827, 829, 831, 833, 837, 839, 843, 847, 849, 851, 853, 857, 859, 861, 863, 867, 869, 871, 873, 877, 879, 881, 883, 887, 889, 891, 893, 897, 901, 903, 907, 909, 911, 913, 917, 919, 921, 923, 927, 929, 931, 933, 937, 939, 941, 943, 947, 949, 951, 953, 959, 961, 963, 967, 969, 971, 973, 977, 979, 981, 983, 987, 989, 991, 993, 997, 999, 1001, 1003, 1007, 1009, 1011, 1013, 1017, 1019, 1021, 1023, 1027, 1029, 1031, 1033, 1037, 1039, 1041, 1043, 1047, 1049, 1051, 1053, 1057, 1059, 1061, 1063, 1067, 1069, 1071, 1077, 1079, 1081, 1083, 1087, 1089, 1091, 1093, 1097, 1099, 1101, 1103, 1107, 1109, 1111, 1113, 1117, 1119, 1121, 1123, 1127, 1129, 1133, 1137, 1139, 1141, 1143, 1147, 1149, 1151, 1153, 1157, 1159, 1161, 1163, 1167, 1169, 1171, 1173, 1177, 1179, 1181, 1183, 1187, 1191, 1193, 1197, 1199, 1201, 1203, 1207, 1209, 1211, 1213, 1217, 1219, 1221, 1223, 1227, 1229, 1231, 1233, 1237, 1239, 1241, 1243, 1249, 1251, 1253, 1257, 1259, 1261, 1263, 1267, 1269, 1271, 1273, 1277, 1279, 1281, 1283, 1287, 1289, 1291, 1293, 1297, 1299, 1301, 1303, 1307, 1309, 1311, 1313, 1317, 1319, 1321, 1323, 1327, 1329, 1331, 1333, 1337, 1339, 1341, 1343, 1347, 1349, 1351, 1353, 1357, 1359, 1361, 1367, 1369, 1371, 1373, 1377, 1379, 1381, 1383, 1387, 1389, 1391, 1393, 1397, 1399, 1401, 1403, 1407, 1409, 1411, 1413, 1417, 1419, 1423, 1427, 1429, 1431, 1433, 1437, 1439, 1441, 1443, 1447, 1449, 1451, 1453, 1457, 1459, 1461, 1463, 1467, 1469, 1471, 1473, 1477, 1481, 1483, 1487, 1489, 1491, 1493, 1497, 1499, 1501, 1503, 1507, 1509, 1511, 1513, 1517, 1519, 1521, 1523, 1527, 1529, 1531, 1533, 1539, 1541, 1543, 1547, 1549, 1551, 1553, 1557, 1559, 1561, 1563, 1567, 1569, 1571, 1573, 1577, 1579, 1581, 1583, 1587, 1589, 1591, 1593, 1597, 1599, 1601, 1603, 1607, 1609, 1611, 1613, 1617, 1619, 1621, 1623, 1627, 1629, 1631, 1633, 1637, 1639, 1641, 1643, 1647, 1649, 1651, 1657, 1659, 1661, 1663, 1667, 1669, 1671, 1673, 1677, 1679, 1681, 1683, 1687, 1689, 1691, 1693, 1697, 1699, 1701, 1703, 1707, 1709, 1713, 1717, 1719, 1721, 1723, 1727, 1729, 1731, 1733, 1737, 1739, 1741, 1743, 1747, 1749, 1751, 1753, 1757, 1759, 1761, 1763, 1767, 1771, 1773, 1777, 1779, 1781, 1783, 1787, 1789, 1791, 1793, 1797, 1799, 1801, 1803, 1807, 1809, 1811, 1813, 1817, 1819, 1821, 1823, 1829, 1831, 1833, 1837, 1839, 1841, 1843, 1847, 1849, 1851, 1853, 1857, 1859, 1861, 1863, 1867, 1869, 1871, 1873, 1877, 1879, 1881, 1883, 1887, 1889, 1891, 1893, 1897, 1899, 1901, 1903, 1907, 19 ...
#
# Tiempo de ejecución del Metodo Totient de Euler: 11.92 segundos.
# → Número de Generadores Cíclicos de G: --- φ(14500) = 5600 ---
# → Por este Metodo, no se obtiene los elementos de los SubGrupos generados por G.

# %% [markdown]
# ### Metodo Tradicional:
# ##### Comprobar si el subgrupo generado por cada elemento es el Grupo Cíclico de G.

# %%
###### Se calcula cada subgrupo generado por cada elemento (y se almacena en un Set). Luego, se comprueba su tamaño:

# %%
def generador(numGenerador):
    SubGrupo = set()
    strIndice = ""
    for indice in Grupo:
        SubGrupo.add(indice * numGenerador % n)
        if indice * numGenerador % n == 0:
            break
    for digit in str(numGenerador):
        strIndice = strIndice + imprimirSuperIndice(int(digit))
    if len(SubGrupo) == len(Grupo):
        print("< a" + strIndice + "> = " + bold("--- Grupo Cíclico de G ---"))
        return True
    else:
        mcd = calcularMCDconGrupo(numGenerador)
        if mcd == numGenerador or mcd == 1:
            print("< a" + strIndice + "> = ", end="")
            print(SubGrupo)
        else:
            print("< a" + strIndice + "> = " + "Subgrupo Cíclico generado por " + str(mcd))

        return False

# %%
def imprimirMetodoTradicional():
    print("                                   " + bold("Orden del Grupo G: " + str(n)) + "\n")
    print(bold("→ Generadores Cíclicos de G:"))
    print(bold("|") + " { " + ', '.join(str(x) for x in GeneradoresGCiclico) + " } " + bold("|" + " = " + str(numGeneradoresGCiclico))+ "\n")

    print("Tiempo de ejecución del " + bold("Metodo Tradicional") + ": " + str(Tiempo1) + " segundos.")
    print(bold("→ Número de Generadores Cíclicos de G: --- φ(" + str(n) + ") = " + str(numGeneradoresGCiclico) + " ---"))

# %% [markdown]
# ###### Ejecutar el Método Tradicional:

# %%
GeneradoresGCiclico = []
numGeneradoresGCiclico=0
inicio1 = time.time()

for num in Grupo:
    if generador(num):
        numGeneradoresGCiclico+=1
        GeneradoresGCiclico.append(num)

fin1 = time.time()
Tiempo1 = round(fin1-inicio1,2)

imprimirMetodoTradicional()
# Out:
# < a¹> = --- Grupo Cíclico de G ---
# < a²> = {0, 2, 4, 6, 8, 10}
# < a³> = {0, 9, 3, 6}
# < a⁴> = {8, 0, 4}
# < a⁵> = --- Grupo Cíclico de G ---
# < a⁶> = {0, 6}
# < a⁷> = --- Grupo Cíclico de G ---
# < a⁸> = Subgrupo Cíclico generado por 4
# < a⁹> = Subgrupo Cíclico generado por 3
# < a¹⁰> = Subgrupo Cíclico generado por 2
# < a¹¹> = --- Grupo Cíclico de G ---
# < a¹²> = {0}
#                                    Orden del Grupo G: 12
#
# → Generadores Cíclicos de G:
# | { 1, 5, 7, 11 } | = 4
#
# Tiempo de ejecución del Metodo Tradicional: 0.01 segundos.
# → Número de Generadores Cíclicos de G: --- φ(12) = 4 ---

# %%
##### Muchas Gracias. Desarrollado por David Santiago Cruz Hernandez. Correo: dcruzhe@unal.edu.co
